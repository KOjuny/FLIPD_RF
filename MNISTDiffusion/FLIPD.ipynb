# %%
import os

os.chdir("/content/drive/MyDrive/AI-ISL/MNISTDiffusion")

# %%
pwd
# Out:
# '/content/drive/MyDrive/AI-ISL/MNISTDiffusion'

# %%
import torch
from torchvision.utils import save_image
from model import MNISTDiffusion
from utils import ExponentialMovingAverage
import math
import os

# %%
ckpt_path = "results/steps_00046900.pt"   # ✅ 저장된 체크포인트 경로
n_samples = 1                             # ✅ 생성할 샘플 개수
model_base_dim = 64                       # ✅ 학습할 때 사용했던 base dim
timesteps = 1000                          # ✅ 학습할 때 사용했던 diffusion steps
no_clip = False                           # ✅ x_0 clipping 쓸지 여부
use_cpu = False                           # ✅ True면 CPU 사용, False면 GPU 사용
device = "cpu" if use_cpu else "cuda"

# %%
def load_model(ckpt_path, device, image_size=28, in_channels=1, model_base_dim=64, timesteps=1000):
    model = MNISTDiffusion(
        timesteps=timesteps,
        image_size=image_size,
        in_channels=in_channels,
        base_dim=model_base_dim,
        dim_mults=[2, 4]
    ).to(device)

    model_ema = ExponentialMovingAverage(model, device=device, decay=0.0)  # decay는 중요 X (로드할 거니까)

    # checkpoint 로드
    ckpt = torch.load(ckpt_path, map_location=device)
    model.load_state_dict(ckpt["model"])
    model_ema.load_state_dict(ckpt["model_ema"])

    return model_ema

# %%
# 모델 로드
model_ema = load_model(
    ckpt_path=ckpt_path,
    device=device,
    image_size=28,
    in_channels=1,
    model_base_dim=model_base_dim,
    timesteps=timesteps
)

model_ema.eval()
# Out:
# ExponentialMovingAverage(
#   (module): MNISTDiffusion(
#     (model): Unet(
#       (init_conv): ConvBnSiLu(
#         (module): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#       )
#       (time_embedding): Embedding(1000, 256)
#       (encoder_blocks): ModuleList(
#         (0): EncoderBlock(
#           (conv0): Sequential(
#             (0): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (1): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (2): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (3): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#                 (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#           )
#           (time_mlp): TimeMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=256, out_features=128, bias=True)
#               (1): SiLU()
#               (2): Linear(in_features=128, out_features=64, bias=True)
#             )
#             (act): SiLU()
#           )
#           (conv1): ResidualDownsample(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#         (1): EncoderBlock(
#           (conv0): Sequential(
#             (0): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (1): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (2): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (3): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#           )
#           (time_mlp): TimeMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=256, out_features=256, bias=True)
#               (1): SiLU()
#               (2): Linear(in_features=256, out_features=128, bias=True)
#             )
#             (act): SiLU()
#           )
#           (conv1): ResidualDownsample(
#             (branch1): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#               (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#       )
#       (decoder_blocks): ModuleList(
#         (0): DecoderBlock(
#           (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#           (conv0): Sequential(
#             (0): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (1): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (2): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (3): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#                 (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#           )
#           (time_mlp): TimeMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=256, out_features=256, bias=True)
#               (1): SiLU()
#               (2): Linear(in_features=256, out_features=128, bias=True)
#             )
#             (act): SiLU()
#           )
#           (conv1): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#               (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#         (1): DecoderBlock(
#           (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#           (conv0): Sequential(
#             (0): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (1): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (2): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#             (3): ResidualBottleneck(
#               (branch1): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (branch2): Sequential(
#                 (0): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#                 (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#                 (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): ConvBnSiLu(
#                   (module): Sequential(
#                     (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#                     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (2): SiLU(inplace=True)
#                   )
#                 )
#               )
#               (channel_shuffle): ChannelShuffle()
#             )
#           )
#           (time_mlp): TimeMLP(
#             (mlp): Sequential(
#               (0): Linear(in_features=256, out_features=128, bias=True)
#               (1): SiLU()
#               (2): Linear(in_features=128, out_features=64, bias=True)
#             )
#             (act): SiLU()
#           )
#           (conv1): ResidualBottleneck(
#             (branch1): Sequential(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (branch2): Sequential(
#               (0): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#               (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#               (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (3): ConvBnSiLu(
#                 (module): Sequential(
#                   (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#                   (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#               )
#             )
#             (channel_shuffle): ChannelShuffle()
#           )
#         )
#       )
#       (mid_block): Sequential(
#         (0): ResidualBottleneck(
#           (branch1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (branch2): Sequential(
#             (0): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (channel_shuffle): ChannelShuffle()
#         )
#         (1): ResidualBottleneck(
#           (branch1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (branch2): Sequential(
#             (0): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (channel_shuffle): ChannelShuffle()
#         )
#         (2): ResidualBottleneck(
#           (branch1): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (branch2): Sequential(
#             (0): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#             (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ConvBnSiLu(
#               (module): Sequential(
#                 (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): SiLU(inplace=True)
#               )
#             )
#           )
#           (channel_shuffle): ChannelShuffle()
#         )
#       )
#       (final_conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
# 샘플 생성
samples, flipd = model_ema.module.sampling(
    n_samples=n_samples,
    clipped_reverse_diffusion=not no_clip,
    device=device
)

# # 결과 저장
# os.makedirs("inference_results", exist_ok=True)
# save_image(samples, "inference_results/generated_samples.png", nrow=int(math.sqrt(n_samples)))

# print(f"✅ 샘플 이미지를 'inference_results/generated_samples.png'로 저장 완료했습니다!")
# Out:
# Sampling: 100%|█████████▉| 999/1000 [01:14<00:00, 13.49it/s]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-0c97caa14be6> in <cell line: 0>()
#       1 # 샘플 생성
# ----> 2 samples, flipd = model_ema.module.sampling(
#       3     n_samples=n_samples,
#       4     clipped_reverse_diffusion=not no_clip,
#       5     device=device
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /content/drive/MyDrive/AI-ISL/MNISTDiffusion/model.py in sampling(self, n_samples, clipped_reverse_diffusion, device)
#      43
#      44             if clipped_reverse_diffusion:
# ---> 45                 x_t, flipd=self._reverse_diffusion_with_clip(x_t,t,noise)
#      46                 flipd_lst.append(flipd)
#      47                 # if t != 1000 and t != 0:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /content/drive/MyDrive/AI-ISL/MNISTDiffusion/model.py in _reverse_diffusion_with_clip(self, x_t, t, noise)
#     158             flipd = self.in_channels * self.image_size**2 + std**2 * (flipd_trace_term + flipd_score_norm_term**2)
#     159
# --> 160             return mean+std*noise, flipd.item()
#     161         else:
#     162             return mean+std*noise, 0
#
# UnboundLocalError: cannot access local variable 'flipd' where it is not associated with a value

# %%
import matplotlib.pyplot as plt


plt.plot(flipd)
plt.title("Line Plot of List")
plt.xlabel("Index")
plt.ylabel("Value")
plt.xlim(0, 1)
plt.grid(True)
plt.show()
