# %%
import os

os.chdir("/content/drive/MyDrive/AI-ISL/MNISTDiffusion")

# %%
pwd
# Out:
# '/content/drive/MyDrive/AI-ISL/MNISTDiffusion'

# %%
# !pip install tqdm

# %%
# !python train_mnist_colab.py
# Out:
# 100% 9.91M/9.91M [00:01<00:00, 5.01MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 136kB/s]
# 100% 1.65M/1.65M [00:01<00:00, 1.27MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 10.8MB/s]
# Epoch[1/100], Step[0/469], loss: 1.11827, lr: 0.00004
# Epoch[1/100], Step[10/469], loss: 1.09863, lr: 0.00004
# Epoch[1/100], Step[20/469], loss: 1.08455, lr: 0.00004
# Epoch[1/100], Step[30/469], loss: 1.07069, lr: 0.00004
# Epoch[1/100], Step[40/469], loss: 1.04013, lr: 0.00004
# Epoch[1/100], Step[50/469], loss: 1.02341, lr: 0.00004
# Epoch[1/100], Step[60/469], loss: 1.01100, lr: 0.00004
# Epoch[1/100], Step[70/469], loss: 0.99306, lr: 0.00004
# Epoch[1/100], Step[80/469], loss: 0.98769, lr: 0.00004
# Epoch[1/100], Step[90/469], loss: 0.96211, lr: 0.00004
# Epoch[1/100], Step[100/469], loss: 0.94824, lr: 0.00004
# Epoch[1/100], Step[110/469], loss: 0.94455, lr: 0.00004
# Epoch[1/100], Step[120/469], loss: 0.92274, lr: 0.00004
# Epoch[1/100], Step[130/469], loss: 0.90977, lr: 0.00004
# ...
